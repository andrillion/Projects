# %% [markdown]
# <a href="https://colab.research.google.com/github/andrillion/Projects/blob/master/Customer_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Churn Prediction

# %% [markdown]
# ### 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, make_scorer

import xgboost as xgb
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
print(os.getcwd())
# Out:
# /content/drive/My Drive

# %%
# %cd /content/drive/My Drive/
# !pwd
# Out:
# /content/drive/My Drive
# /content/drive/My Drive

# %%
import pandas as pd

# Full file path
file_path = '/content/drive/My Drive/churn.xlsx'
#file_path = '/content/drive/My Drive/fpl_.csv'


# Read the CSV file into a DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame
df.head(50)
# Out:
#     CustomerID  Count        Country       State             City  Zip Code  \
# 0   3668-QPYBK      1  United States  California      Los Angeles     90003
# 1   9237-HQITU      1  United States  California      Los Angeles     90005
# 2   9305-CDSKC      1  United States  California      Los Angeles     90006
# 3   7892-POOKP      1  United States  California      Los Angeles     90010
# 4   0280-XJGEX      1  United States  California      Los Angeles     90015
# 5   4190-MFLUW      1  United States  California      Los Angeles     90020
# 6   8779-QRDMV      1  United States  California      Los Angeles     90022
# 7   1066-JKSGK      1  United States  California      Los Angeles     90024
# 8   6467-CHFZW      1  United States  California      Los Angeles     90028
# 9   8665-UTDHZ      1  United States  California      Los Angeles     90029
# 10  8773-HHUOZ      1  United States  California      Los Angeles     90032
# ...

# %% [markdown]
# ### 2. Remove columns

# %%
df.drop(['Churn Label', 'Churn Score', 'CLTV', 'Churn Reason'], axis = 1, inplace = True)

df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Device Protection Tech Support Streaming TV  Streaming Movies  \
# 0                No           No           No                No
# ...

# %%
for column in df.columns:
    if df[column].nunique() == 1:
        print(f"Column '{column}' has only one unique value.")
# Out:
# Column 'Count' has only one unique value.
# Column 'Country' has only one unique value.
# Column 'State' has only one unique value.

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Value'],
#       dtype='object')

# %%
df.drop(['CustomerID', 'Count', 'Country', 'State', 'Lat Long'], axis = 1, inplace = True)

df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df['City'].replace(' ', '_', regex=True, inplace=True)

df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')

df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ### 3. Handle missing data

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df.count()
# Out:
# City                 7043
# Zip_Code             7043
# Latitude             7043
# Longitude            7043
# Gender               7043
# Senior_Citizen       7043
# Partner              7043
# Dependents           7043
# Tenure_Months        7043
# Phone_Service        7043
# Multiple_Lines       7043
# Internet_Service     7043
# Online_Security      7043
# Online_Backup        7043
# Device_Protection    7043
# Tech_Support         7043
# Streaming_TV         7043
# Streaming_Movies     7043
# Contract             7043
# Paperless_Billing    7043
# Payment_Method       7043
# Monthly_Charges      7043
# Total_Charges        7043
# Churn_Value          7043
# dtype: int64

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# City                 0
# Zip_Code             0
# Latitude             0
# Longitude            0
# Gender               0
# Senior_Citizen       0
# Partner              0
# Dependents           0
# Tenure_Months        0
# Phone_Service        0
# Multiple_Lines       0
# Internet_Service     0
# Online_Security      0
# Online_Backup        0
# Device_Protection    0
# Tech_Support         0
# Streaming_TV         0
# Streaming_Movies     0
# Contract             0
# Paperless_Billing    0
# Payment_Method       0
# Monthly_Charges      0
# Total_Charges        0
# Churn_Value          0
# dtype: int64

# %%
empty_strings = (df == " ").sum()
print(empty_strings)
# Out:
# City                  0
# Zip_Code              0
# Latitude              0
# Longitude             0
# Gender                0
# Senior_Citizen        0
# Partner               0
# Dependents            0
# Tenure_Months         0
# Phone_Service         0
# Multiple_Lines        0
# Internet_Service      0
# Online_Security       0
# Online_Backup         0
# Device_Protection     0
# Tech_Support          0
# Streaming_TV          0
# Streaming_Movies      0
# Contract              0
# Paperless_Billing     0
# Payment_Method        0
# Monthly_Charges       0
# Total_Charges        11
# Churn_Value           0
# dtype: int64

# %%
empty_rows = df.loc[df['Total_Charges'] == " "]

empty_rows
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df.loc[df['Total_Charges'] == " ", 'Total_Charges'] = 0

# %%
df.loc[df['Tenure_Months'] == 0]
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
df['Total_Charges'].dtype # data type is an object
# Out:
# dtype('O')

# %%
df['Total_Charges'].astype(float) # convert to float
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df.replace(' ', '_', regex = True, inplace = True)
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ### 4. Split the dataset into X(features) and y(target)

# %%
X = df.drop('Churn_Value', axis = 1).copy()
X.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Online_Backup  \
# 0      No         No              2           Yes  ...           Yes
# 1      No        Yes              2           Yes  ...            No
# 2      No        Yes              8           Yes  ...            No
# 3     Yes        Yes             28           Yes  ...            No
# 4      No        Yes             49           Yes  ...           Yes
#
#   Device_Protection Tech_Support Streaming_TV Streaming_Movies  \
# ...

# %%
y = df['Churn_Value'].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %% [markdown]
# ### 5. Use One Hot Encoding to convert categorical features (objects)

# %%
X.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# dtype: object

# %%
X.columns
# Out:
# Index(['City', 'Zip_Code', 'Latitude', 'Longitude', 'Gender', 'Senior_Citizen',
#        'Partner', 'Dependents', 'Tenure_Months', 'Phone_Service',
#        'Multiple_Lines', 'Internet_Service', 'Online_Security',
#        'Online_Backup', 'Device_Protection', 'Tech_Support', 'Streaming_TV',
#        'Streaming_Movies', 'Contract', 'Paperless_Billing', 'Payment_Method',
#        'Monthly_Charges', 'Total_Charges'],
#       dtype='object')

# %%
X_encoded = pd.get_dummies(X, columns = ['City', 'Gender', 'Senior_Citizen',
       'Partner', 'Dependents', 'Phone_Service',
       'Multiple_Lines', 'Internet_Service', 'Online_Security',
       'Online_Backup', 'Device_Protection', 'Tech_Support', 'Streaming_TV',
       'Streaming_Movies', 'Contract', 'Paperless_Billing', 'Payment_Method']).astype(int)

X_encoded.head()
# Out:
#    Zip_Code  Latitude  Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003        33       -118              2               53
# 1     90005        34       -118              2               70
# 2     90006        34       -118              8               99
# 3     90010        34       -118             28              104
# 4     90015        34       -118             49              103
#
#    Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# 0            108            0           0              0          0  ...
# 1            151            0           0              0          0  ...
# 2            820            0           0              0          0  ...
# 3           3046            0           0              0          0  ...
# 4           5036            0           0              0          0  ...
#
#    Streaming_Movies_Yes  Contract_Month-to-month  Contract_One_year  \
# ...

# %%
y.unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### 6. Create a train and test split

# %%
sum(y)/len(y) #unbalanced, since only 27% churn, so we need to stratify when doing the train test split
# Out:
# 0.2653698707936959

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size = 0.2, random_state = 42, stratify = y)

# %%
sum(y_train)/len(y_train)
# Out:
# 0.2653532126375577

# %%
sum(y_test)/len(y_test)
# Out:
# 0.2654364797728886

# %%
clf_xgb = xgb.XGBClassifier(objective:= 'binary:logistic', eval_metric='aucpr', seed = 42)
clf_xgb.fit(X_train, y_train, verbose = True, eval_set = [(X_test, y_test)])
# Out:
# [0]	validation_0-aucpr:0.64953
# [1]	validation_0-aucpr:0.65817
# [2]	validation_0-aucpr:0.65731
# [3]	validation_0-aucpr:0.66194
# [4]	validation_0-aucpr:0.65739
# [5]	validation_0-aucpr:0.65762
# [6]	validation_0-aucpr:0.65764
# [7]	validation_0-aucpr:0.65924
# [8]	validation_0-aucpr:0.66190
# [9]	validation_0-aucpr:0.65974
# [10]	validation_0-aucpr:0.66073
# [11]	validation_0-aucpr:0.65986
# [12]	validation_0-aucpr:0.65946
# [13]	validation_0-aucpr:0.66310
# [14]	validation_0-aucpr:0.66318
# [15]	validation_0-aucpr:0.66295
# [16]	validation_0-aucpr:0.66283
# [17]	validation_0-aucpr:0.66208
# [18]	validation_0-aucpr:0.66267
# [19]	validation_0-aucpr:0.66227
# [20]	validation_0-aucpr:0.66168
# [21]	validation_0-aucpr:0.66177
# [22]	validation_0-aucpr:0.66199
# [23]	validation_0-aucpr:0.66256
# [24]	validation_0-aucpr:0.66226
# [25]	validation_0-aucpr:0.66239
# [26]	validation_0-aucpr:0.66080
# [27]	validation_0-aucpr:0.66001
# [28]	validation_0-aucpr:0.65773
# ...

# %%
# Predict on the validation set
y_pred = clf_xgb.predict(X_test)

# %%
# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[911, 124],
#        [173, 201]])

# %%
# Plotting the confusion matrix with appropriate labels for churn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Churned', 'Churned'],
            yticklabels=['Not Churned', 'Churned'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Churn Prediction')
plt.show()

# %% [markdown]
# ### 7. Hyperparameter tuning with GridsearchCV

# %%
# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [100, 200],            # Number of boosting rounds
    'learning_rate': [0.01, 0.1],         # Learning rate
    'max_depth': [3, 5, 7],                     # Maximum depth of a tree
    'gamma': [0, 0.1, 0.2],                     # Minimum loss reduction required to make a further partition on a leaf node
    'min_child_weight': [1, 3, 5]               # Minimum sum of instance weight (hessian) needed in a child
}

# Set up GridSearchCV with 3-fold cross-validation
grid_search = GridSearchCV(
    estimator=clf_xgb,
    param_grid=param_grid,
    scoring='roc_auc',            # Scoring metric to optimize
    cv=3,                         # 3-fold cross-validation
    verbose=1,                    # Verbosity of the output
    n_jobs=-1                     # Use all available cores
)

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, y_train)

# Best parameters found by GridSearchCV
print("Best Parameters:", grid_search.best_params_)
print("Best AUC Score:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
